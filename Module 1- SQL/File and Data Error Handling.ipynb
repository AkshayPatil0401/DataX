# %% [markdown]
# # File and Data Error Handling and Logging

# %%
# %sql
select * from customers limit 10;

# %%
class Customer:
  def __init__(self,name):
    self.name = name

# %%
c1=Customer('John')
c2=Customer('Mary')
c3=Customer('Jane')
c4=Customer('Bob')
c5=Customer('Alice')

# %%
print(c2.name)
